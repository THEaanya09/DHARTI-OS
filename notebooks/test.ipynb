# %%
import joblib

crop = joblib.load(r"C:\Users\sh\OneDrive\Desktop\CODE\coding\DHARTI-OS\backend\models\crop_yield_model.pkl")
flood = joblib.load(r"C:\Users\sh\OneDrive\Desktop\CODE\coding\DHARTI-OS\backend\models\flood_model.pkl")
rec = joblib.load(r"C:\Users\sh\OneDrive\Desktop\CODE\coding\DHARTI-OS\backend\models\crop_recommendation_model.pkl")

print("Crop:", type(crop))
print("Flood:", type(flood))
print("Recommendation:", type(rec))

if isinstance(crop, dict):
    print("Crop keys:", crop.keys())

if isinstance(flood, dict):
    print("Flood keys:", flood.keys())

if isinstance(rec, dict):
    print("Recommendation keys:", rec.keys())
# Out:
# Crop: <class 'sklearn.compose._target.TransformedTargetRegressor'>
# Flood: <class 'sklearn.pipeline.Pipeline'>
# Recommendation: <class 'dict'>
# Recommendation keys: dict_keys(['model', 'label_encoder', 'features'])
